# %%
import deepxde1 as dde
import numpy as np
import random
# Out:
# Deepxde backend not selected or invalid. Assuming tensorflow.compat.v1 for now.
# Using backend: tensorflow
# Setting the default backend to "pytorch". You can change it in the ~/.deepxde/config.json file or export the DDEBACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax (all lowercase)
# 2024-08-21 13:52:17.278688: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-08-21 13:52:17.278720: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def gen_testdata():
    data = np.load("Burgers.npz")
    t, x, exact = data["t"], data["x"], data["usol"].T
    xx, tt = np.meshgrid(x, t)
    X = np.vstack((np.ravel(xx), np.ravel(tt))).T
    y = exact.flatten()[:, None]
    return X, y

# %%
def pde(x, y):
    e = 2.718281828459045
    dy_x = dde.grad.jacobian(y, x, i=0, j=0)
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    x = x[:, 0:1]
    return dy_t + y * dy_x - 0.01 / np.pi * dy_xx + e**(-(x * random.random())**2) * 0.1

# %%
geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 0.99)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# %%
bc = dde.icbc.DirichletBC(geomtime, lambda x: 0, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(
    geomtime, lambda x: -np.sin(np.pi * x[:, 0:1]), lambda _, on_initial: on_initial
)

# %%
data = dde.data.TimePDE(
    geomtime, pde, [bc, ic], num_domain=2540, num_boundary=80, num_initial=160
)
net = dde.nn.FNN([2] + [20] * 3 + [1], "tanh", "Glorot normal")
model = dde.Model(data, net)

model.compile("yogi", lr=1e-3)
model.train(epochs=30000)
model.compile("L-BFGS")
losshistory, train_state = model.train()
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Compiling model...
# 'compile' took 0.000344 s
# /home/ruslan/anaconda3/lib/python3.9/site-packages/skopt/sampler/sobol.py:246: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+2542=2542.
#   warnings.warn("The balance properties of Sobol' points require "
# /home/ruslan/anaconda3/lib/python3.9/site-packages/skopt/sampler/sobol.py:246: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+82=82.
#   warnings.warn("The balance properties of Sobol' points require "
# /home/ruslan/anaconda3/lib/python3.9/site-packages/skopt/sampler/sobol.py:246: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+162=162.
#   warnings.warn("The balance properties of Sobol' points require "
# 2024-08-21 13:52:20.161986: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-08-21 13:52:20.162091: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-08-21 13:52:20.162141: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ruslan-Inspiron-5770): /proc/driver/nvidia/version does not exist
# 2024-08-21 13:52:20.162454: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training model...
#
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7f43eb46f670> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7f43eb46f670>: no matching AST found among candidates:
# # coding=utf-8
# lambda x, on: np.array([on_boundary(x[i], on[i]) for i in range(len(x))])
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7f43eb46f670> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7f43eb46f670>: no matching AST found among candidates:
# # coding=utf-8
# lambda x, on: np.array([on_boundary(x[i], on[i]) for i in range(len(x))])
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7f43eb46f8b0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7f43eb46f8b0>: no matching AST found among candidates:
# # coding=utf-8
# lambda x, on: np.array([on_boundary(x[i], on[i]) for i in range(len(x))])
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7f43eb46f8b0> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7f43eb46f8b0>: no matching AST found among candidates:
# # coding=utf-8
# lambda x, on: np.array([on_boundary(x[i], on[i]) for i in range(len(x))])
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Step      Train loss                        Test loss                         Test metric
# 0         [3.50e-03, 4.82e-02, 3.64e-01]    [4.35e-03, 4.82e-02, 3.64e-01]    []
# 1000      [5.47e-02, 4.95e-03, 7.61e-02]    [5.49e-02, 4.95e-03, 7.61e-02]    []
# 2000      [4.88e-02, 2.18e-03, 6.75e-02]    [4.90e-02, 2.18e-03, 6.75e-02]    []
# 3000      [3.51e-02, 7.08e-04, 5.20e-02]    [3.52e-02, 7.08e-04, 5.20e-02]    []
# 4000      [1.63e-02, 3.52e-04, 1.73e-02]    [1.66e-02, 3.52e-04, 1.73e-02]    []
# 5000      [9.36e-03, 1.63e-04, 8.12e-03]    [9.56e-03, 1.63e-04, 8.12e-03]    []
# 6000      [6.01e-03, 8.46e-05, 4.90e-03]    [6.26e-03, 8.46e-05, 4.90e-03]    []
# 7000      [4.86e-03, 6.67e-05, 3.44e-03]    [5.08e-03, 6.67e-05, 3.44e-03]    []
# 8000      [3.49e-03, 5.25e-05, 2.25e-03]    [3.69e-03, 5.25e-05, 2.25e-03]    []
# 9000      [2.35e-03, 4.28e-05, 1.45e-03]    [2.57e-03, 4.28e-05, 1.45e-03]    []
# 10000     [2.17e-03, 7.42e-05, 9.84e-04]    [2.39e-03, 7.42e-05, 9.84e-04]    []
# 11000     [1.29e-03, 7.85e-05, 7.27e-04]    [1.53e-03, 7.85e-05, 7.27e-04]    []
# 12000     [1.53e-03, 1.15e-04, 5.95e-04]    [1.78e-03, 1.15e-04, 5.95e-04]    []
# 13000     [1.20e-03, 6.30e-05, 5.05e-04]    [1.44e-03, 6.30e-05, 5.05e-04]    []
# 14000     [1.00e-03, 4.71e-05, 4.38e-04]    [1.23e-03, 4.71e-05, 4.38e-04]    []
# 15000     [8.52e-04, 4.16e-05, 3.72e-04]    [1.08e-03, 4.16e-05, 3.72e-04]    []
# 16000     [8.20e-04, 4.04e-05, 3.63e-04]    [1.04e-03, 4.04e-05, 3.63e-04]    []
# 17000     [9.65e-04, 2.68e-05, 4.59e-04]    [1.18e-03, 2.68e-05, 4.59e-04]    []
# 18000     [6.81e-04, 3.00e-05, 3.25e-04]    [8.88e-04, 3.00e-05, 3.25e-04]    []
# 19000     [5.80e-04, 2.71e-05, 2.61e-04]    [7.84e-04, 2.71e-05, 2.61e-04]    []
# 20000     [1.52e-02, 3.44e-03, 3.16e-03]    [1.55e-02, 3.44e-03, 3.16e-03]    []
# 21000     [4.16e-04, 2.30e-05, 2.08e-04]    [6.06e-04, 2.30e-05, 2.08e-04]    []
# 22000     [6.95e-04, 2.15e-05, 3.80e-04]    [8.98e-04, 2.15e-05, 3.80e-04]    []
# 23000     [3.69e-04, 1.81e-05, 2.23e-04]    [5.65e-04, 1.81e-05, 2.23e-04]    []
# 24000     [3.14e-04, 1.99e-05, 1.45e-04]    [5.06e-04, 1.99e-05, 1.45e-04]    []
# 25000     [6.20e-04, 6.00e-05, 3.24e-04]    [7.94e-04, 6.00e-05, 3.24e-04]    []
# 26000     [5.98e-04, 2.31e-04, 3.01e-04]    [7.30e-04, 2.31e-04, 3.01e-04]    []
# 27000     [3.58e-04, 1.37e-05, 1.76e-04]    [5.79e-04, 1.37e-05, 1.76e-04]    []
# 28000     [1.07e-03, 2.76e-05, 3.76e-04]    [1.27e-03, 2.76e-05, 3.76e-04]    []
# 29000     [4.44e-04, 3.88e-05, 1.43e-04]    [6.39e-04, 3.88e-05, 1.43e-04]    []
# 30000     [3.60e-04, 1.64e-05, 1.24e-04]    [5.36e-04, 1.64e-05, 1.24e-04]    []
#
# Best model at step 24000:
#   train loss: 4.80e-04
#   test loss: 6.72e-04
#   test metric: []
#
# 'train' took 148.855566 s
#
# Compiling model...
# 'compile' took 0.026969 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 30000     [3.93e-04, 1.64e-05, 1.24e-04]    [8.66e-04, 1.64e-05, 1.24e-04]    []
#
# Best model at step 39543:
#   train loss: 2.58e-04
#   test loss: 5.98e-04
#   test metric: []
#
# 'train' took 845.536438 s
#
# Saving loss history to /home/ruslan/Музыка/DeepXDE/deepxde-master/loss.dat ...
# Saving training data to /home/ruslan/Музыка/DeepXDE/deepxde-master/train.dat ...
# Saving test data to /home/ruslan/Музыка/DeepXDE/deepxde-master/test.dat ...

# %%
X, y_true = gen_testdata()
y_pred = model.predict(X)
f = model.predict(X, operator=pde)
print("Mean residual:", np.mean(np.absolute(f)))
print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))
# Out:
# Mean residual: 0.3510227
# L2 relative error: 0.2719679312668893

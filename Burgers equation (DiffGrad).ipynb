# 19000     [6.65e-04, 1.62e-06, 7.15e-04]    [6.65e-04, 1.62e-06, 7.15e-04]    []
# 20000     [6.25e-04, 1.44e-06, 6.71e-04]    [6.25e-04, 1.44e-06, 6.71e-04]    []
# 21000     [5.86e-04, 1.30e-06, 6.27e-04]    [5.86e-04, 1.30e-06, 6.27e-04]    []
# 22000     [5.55e-04, 1.13e-06, 5.91e-04]    [5.55e-04, 1.13e-06, 5.91e-04]    []
# 23000     [5.24e-04, 9.82e-07, 5.53e-04]    [5.24e-04, 9.82e-07, 5.53e-04]    []
# 24000     [4.99e-04, 8.77e-07, 5.20e-04]    [4.99e-04, 8.77e-07, 5.20e-04]    []
# 25000     [4.76e-04, 7.73e-07, 4.92e-04]    [4.76e-04, 7.73e-07, 4.92e-04]    []
# 26000     [4.54e-04, 6.82e-07, 4.60e-04]    [4.54e-04, 6.82e-07, 4.60e-04]    []
# 27000     [4.38e-04, 6.23e-07, 4.39e-04]    [4.38e-04, 6.23e-07, 4.39e-04]    []
# 28000     [4.19e-04, 5.54e-07, 4.14e-04]    [4.19e-04, 5.54e-07, 4.14e-04]    []
# 29000     [4.03e-04, 5.23e-07, 3.92e-04]    [4.03e-04, 5.23e-07, 3.92e-04]    []
# 30000     [3.86e-04, 4.94e-07, 3.72e-04]    [3.86e-04, 4.94e-07, 3.72e-04]    []
#
# Best model at step 30000:
#   train loss: 7.59e-04
#   test loss: 7.59e-04
#   test metric: []
#
# 'train' took 147.050712 s
#
# Compiling model...
# 'compile' took 0.028868 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 30000     [3.86e-04, 4.94e-07, 3.72e-04]    [3.86e-04, 4.94e-07, 3.72e-04]    []
#
# Best model at step 33609:
#   train loss: 9.36e-06
#   test loss: 9.36e-06
#   test metric: []
#
# 'train' took 438.594648 s
#
# Saving loss history to /home/ruslan/Музыка/DeepXDE/deepxde-master/loss.dat ...
# Saving training data to /home/ruslan/Музыка/DeepXDE/deepxde-master/train.dat ...
# Saving test data to /home/ruslan/Музыка/DeepXDE/deepxde-master/test.dat ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5321/966715468.py in <module>
#      11 dde.saveplot(losshistory, train_state, issave=True, isplot=True)
#      12
# ---> 13 X, y_true = gen_testdata()
#      14 y_pred = model.predict(X)
#      15 f = model.predict(X, operator=pde)
#
# /tmp/ipykernel_5321/2786800164.py in gen_testdata()
#       1 def gen_testdata():
# ----> 2     data = np.load("../dataset/Burgers.npz")
#       3     t, x, exact = data["t"], data["x"], data["usol"].T
#       4     xx, tt = np.meshgrid(x, t)
#       5     X = np.vstack((np.ravel(xx), np.ravel(tt))).T
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425             own_fid = False
#     426         else:
# --> 427             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428             own_fid = True
#     429
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataset/Burgers.npz'

# %%
X, y_true = gen_testdata()
y_pred = model.predict(X)
f = model.predict(X, operator=pde)
print("Mean residual:", np.mean(np.absolute(f)))
print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))
# Out:
# Mean residual: 0.010627956
# L2 relative error: 0.02478709130090294
